# %% [markdown]
# # Dependency Graph for `nbdev-mcp`
#
# > Auto-generated by `dependency_notebook()`. Do not edit manually.

# %% [markdown]
# ## Statistics
#
# | Metric | Count |
# |--------|-------|
# | Internal Modules | 36 |
# | Import Edges | 0 |
# | Unreferenced Modules | 36 |

# %% [markdown]
# ## Module Dependencies
#
# The following diagram shows import relationships between modules:

# %% [markdown]
# ```mermaid
# graph LR
# ```

# %% [markdown]
# ## Unreferenced Modules
#
# These modules are not imported by any other module:
#
# - `nbdev-mcp.__main__`
# - `nbdev-mcp.index`
# - `nbdev-mcp.mcp`
# - `nbdev-mcp.prompts`
# - `nbdev-mcp.resources`
# - `nbdev-mcp.tasks.__init__`
# - `nbdev-mcp.tasks.audit`
# - `nbdev-mcp.tasks.cache`
# - `nbdev-mcp.tasks.core`
# - `nbdev-mcp.tasks.dedup`
# - `nbdev-mcp.tasks.refactor`
# - `nbdev-mcp.tests.agent_e2e`
# - `nbdev-mcp.tools.__init__`
# - `nbdev-mcp.tools.analysis`
# - `nbdev-mcp.tools.editing`
# - `nbdev-mcp.tools.env`
# - `nbdev-mcp.tools.lint`
# - `nbdev-mcp.tools.nbdev`
# - `nbdev-mcp.tools.project`
# - `nbdev-mcp.tools.tests`
# - `nbdev-mcp.utils.__init__`
# - `nbdev-mcp.utils.config`
# - `nbdev-mcp.utils.depgraph`
# - `nbdev-mcp.utils.exceptions`
# - `nbdev-mcp.utils.explore`
# - `nbdev-mcp.utils.extlib`
# - `nbdev-mcp.utils.io`
# - `nbdev-mcp.utils.logs`
# - `nbdev-mcp.utils.md`
# - `nbdev-mcp.utils.nb`
# - `nbdev-mcp.utils.nbformat`
# - `nbdev-mcp.utils.paths`
# - `nbdev-mcp.utils.re`
# - `nbdev-mcp.utils.rich`
# - `nbdev-mcp.utils.subprocess`
# - `nbdev-mcp.utils.types`

# %% [markdown]
# ## All Modules
#
# - `nbdev-mcp.__main__`
# - `nbdev-mcp.index`
# - `nbdev-mcp.mcp`
# - `nbdev-mcp.prompts`
# - `nbdev-mcp.resources`
# - `nbdev-mcp.tasks.__init__`
# - `nbdev-mcp.tasks.audit`
# - `nbdev-mcp.tasks.cache`
# - `nbdev-mcp.tasks.core`
# - `nbdev-mcp.tasks.dedup`
# - `nbdev-mcp.tasks.refactor`
# - `nbdev-mcp.tests.agent_e2e`
# - `nbdev-mcp.tools.__init__`
# - `nbdev-mcp.tools.analysis`
# - `nbdev-mcp.tools.editing`
# - `nbdev-mcp.tools.env`
# - `nbdev-mcp.tools.lint`
# - `nbdev-mcp.tools.nbdev`
# - `nbdev-mcp.tools.project`
# - `nbdev-mcp.tools.tests`
# - `nbdev-mcp.utils.__init__`
# - `nbdev-mcp.utils.config`
# - `nbdev-mcp.utils.depgraph`
# - `nbdev-mcp.utils.exceptions`
# - `nbdev-mcp.utils.explore`
# - `nbdev-mcp.utils.extlib`
# - `nbdev-mcp.utils.io`
# - `nbdev-mcp.utils.logs`
# - `nbdev-mcp.utils.md`
# - `nbdev-mcp.utils.nb`
# - `nbdev-mcp.utils.nbformat`
# - `nbdev-mcp.utils.paths`
# - `nbdev-mcp.utils.re`
# - `nbdev-mcp.utils.rich`
# - `nbdev-mcp.utils.subprocess`
# - `nbdev-mcp.utils.types`
