# %% [markdown]
# # Utils
#
# > Core utilities modules for nbdev project management

# %%
#| default_exp utils.__init__

# %% [markdown]
# ## Imports

# %%
#| hide
from nbdev.showdoc import *

# %% [markdown]
# Can expose utils submodules here if needed

# %%
#| export

# %% [markdown]
# ## Export

# %%
#| hide
import nbdev; nbdev.nbdev_export()
